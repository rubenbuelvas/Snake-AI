# %% [markdown]
# # Práctica 1: Ambiente Snake y Agente Reactivo
# ### [Introducción a los Sistemas Inteligentes 2019-1](https://fagonzalezo.github.io/iis-2019-1/)
# ### Universidad Nacional de Colombia, Bogotá
#
# Rubén Camilo Buelvas Villa
#
# ---
#
# Las siguientes instrucciones instalan las librerías y archivos necesarios para el notebook.

# %%
# !rm -r snake-ai-reinforcement
# !git clone https://github.com/YuriyGuts/snake-ai-reinforcement.git
# !mv snake-ai-reinforcement/snakeai .
# !ls
# Out:
# rm: cannot remove 'snake-ai-reinforcement': No such file or directory
# Cloning into 'snake-ai-reinforcement'...
# remote: Enumerating objects: 197, done.
# remote: Total 197 (delta 0), reused 0 (delta 0), pack-reused 197
# Receiving objects: 100% (197/197), 42.98 KiB | 369.00 KiB/s, done.
# Resolving deltas: 100% (97/97), done.
#  LICENSE    'Search agents.ipynb'   snakeai
#  README.md  'Simple agents.ipynb'   snake-ai-reinforcement

# %% [markdown]
# Vamos a construir un agente que sea capaz de jugar el juego de *Snake*:
#
# <img src="https://cloud.githubusercontent.com/assets/2750531/24808769/cc825424-1bc5-11e7-816f-7320f7bda2cf.gif" alt="Snake snapshot" width="320"/>
#
# Para esto vamos a usar como base este [proyecto](https://github.com/YuriyGuts/snake-ai-reinforcement) desarrollado por [Yuriy Guts](https://github.com/YuriyGuts).
#
# Primero definimos una clase que nos permite simular el juego:

# %%
from snakeai.gameplay.environment import Environment

class EnvironmentPO(Environment):
    """
    Partial observation environment. Same as base class environment, overloads 
    `get_observation` so that only the cells in front of the snake are returned. 
    (From Environment doc): Represents the RL environment for the Snake game that implements the game logic,
    provides rewards for the agent and keeps track of game statistics.
    """
    def __init__(self, config, verbose=0):
        super().__init__(config, verbose)

    @property
    def observation_shape(self):
        """ Get the shape of the state observed at each timestep. """
        return 3

    def get_observation(self):
        """ Observe the state of the environment. """
        if self.is_game_over:
            return (0, 0, 0)
        center = self.snake.head + self.snake.direction
        if self.snake.direction == Point(0,1):
            left = self.snake.head + Point(1,0)
            right = self.snake.head + Point(-1, 0)
        elif self.snake.direction == Point(0, -1):
            left = self.snake.head + Point(-1, 0)
            right = self.snake.head + Point(1, 0)
        elif self.snake.direction == Point(1, 0):
            left = self.snake.head + Point(0, -1)
            right = self.snake.head + Point(0, 1)
        else:
            left = self.snake.head + Point(0, 1)
            right = self.snake.head + Point(0, -1)
        return (self.field[left], self.field[center], self.field[right])
    
    def show_field(self):
        return self.field.__str__()

# %% [markdown]
# Esta clase extiende la clase `Environment` del proyecto `snakeai`:
#
# ```Python
# class Environment(object):
#     """
#     Represents the RL environment for the Snake game that implements the game logic,
#     provides rewards for the agent and keeps track of game statistics.
#     """
#
#     def __init__(self, config, verbose=1):
#         """
#         Create a new Snake RL environment.
#
#         Args:
#             config (dict): level configuration, typically found in JSON configs.
#             verbose (int): verbosity level:
#                 0 = do not write any debug information;
#                 1 = write a CSV file containing the statistics for every episode;
#                 2 = same as 1, but also write a full log file containing the state of each timestep.
#         """
#         self.field = Field(level_map=config['field'])
#         self.snake = None
#         self.fruit = None
#         self.initial_snake_length = config['initial_snake_length']
#         self.rewards = config['rewards']
#         self.max_step_limit = config.get('max_step_limit', 1000)
#         self.is_game_over = False
#
#         self.timestep_index = 0
#         self.current_action = None
#         self.stats = EpisodeStatistics()
#         self.verbose = verbose
#         self.debug_file = None
#         self.stats_file = None
#
#     def seed(self, value):
#
#     @property
#     def observation_shape(self):
#         """ Get the shape of the state observed at each timestep. """
#
#     @property
#     def num_actions(self):
#         """ Get the number of actions the agent can take. """
#
#     def new_episode(self):
#         """ Reset the environment and begin a new episode. """
#
#     def record_timestep_stats(self, result):
#         """ Record environment statistics according to the verbosity level. """
#
#     def get_observation(self):
#         """ Observe the state of the environment. """
#
#     def choose_action(self, action):
#         """ Choose the action that will be taken at the next timestep. """
#
#     def timestep(self):
#         """ Execute the timestep and return the new observable state. """
#
#     def generate_fruit(self, position=None):
#         """ Generate a new fruit at a random unoccupied cell. """
#
#     def has_hit_wall(self):
#         """ True if the snake has hit a wall, False otherwise. """
#
#     def has_hit_own_body(self):
#         """ True if the snake has hit its own body, False otherwise. """
#
#     def is_alive(self):
#         """ True if the snake is still alive, False otherwise. """
# ```

# %% [markdown]
# Un agente para jugar Snake lo construimos extendiendo la clase `AgentBase`. El siguiente es un agente que ejecuta sus acciones al azar:

# %%
from snakeai.agent import AgentBase

class RandomActionAgent(AgentBase):
    """ Represents a Snake agent that takes a random action at every step. """

    def __init__(self):
        pass

    def begin_episode(self):
        pass

    def act(self, observation, reward):
        return random.choice(ALL_SNAKE_ACTIONS)

    def end_episode(self):
        pass

# %% [markdown]
# Finalmente definimos una función `play` que nos permite simular el juego:

# %%
from snakeai.gameplay.entities import ALL_SNAKE_ACTIONS, Point
import numpy as np
import random


def play(env, agent, num_episodes=1, verbose=1):
    """
    Play a set of episodes using the specified Snake agent.
    Use the non-interactive command-line interface and print the summary statistics afterwards.
    
    Args:
        env: an instance of Snake environment.
        agent: an instance of Snake agent.
        num_episodes (int): the number of episodes to run.
    """

    fruit_stats = []

    print()
    print('Playing:')

    for episode in range(num_episodes):
        timestep = env.new_episode()
        agent.begin_episode()
        game_over = False
        step = 0
        while not game_over:
            try:
                if verbose > 0:
                    print("------ Step ", step, " ------")
                    print (env.show_field())
                    print ("Observation:", env.get_observation())
                    print ("Head:", env.snake.head)
                    print ("Direction:", env.snake.direction)
                step += 1
                action = agent.act(timestep.observation, timestep.reward)
                env.choose_action(action)
                timestep = env.timestep()
                game_over = timestep.is_episode_end
            except:
                game_over = True

        fruit_stats.append(env.stats.fruits_eaten)

        summary = '******* Episode {:3d} / {:3d} | Timesteps {:4d} | Fruits {:2d}'
        print(summary.format(episode + 1, num_episodes, env.stats.timesteps_survived, env.stats.fruits_eaten))

    print()
    print('Fruits eaten {:.1f} +/- stddev {:.1f}'.format(np.mean(fruit_stats), np.std(fruit_stats)))

# %% [markdown]
# Ya tenemos todos los elementos necesarios para simular el juego. Arrancamos con un tablero inicial en el cual
# la serpiente está en el centro. Esto lo especificamos con un dictionario que indica la configuración, los campos
# que nos interesan son `field`, `initial_snake_length` y `max_step_limit`, los otros campo los podemo ignorar por el momento:

# %%
inicial = {
  "field": [
    "#######",
    "#.....#",
    "#.....#",
    "#..S..#",
    "#.....#",
    "#.....#",
    "#######"
  ],

  "initial_snake_length": 2,
  "max_step_limit": 1000,

  "rewards": {
    "timestep": -0.01,
    "ate_fruit": 1,
    "died": -1
  }
}

# %% [markdown]
# Veamos como se comporta el agente aleatorio con esta configuración:

# %%
env = EnvironmentPO(config=inicial, verbose=0)
agent = RandomActionAgent()
play(env, agent, num_episodes= 1, verbose=1)
# Out:
# Playing:
# ------ Step  0  ------
# #######
# #.....#
# #.....#
# #.OS..#
# #..s..#
# #.....#
# #######
# Observation: (1, 0, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  1  ------
# #######
# #.....#
# #.....#
# #.OsS.#
# #.....#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=4, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  2  ------
# #######
# #.....#
# #.....#
# #.O.sS#
# #.....#
# #.....#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  3  ------
# #######
# #.....#
# #....S#
# #.O..s#
# #.....#
# #.....#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=-1)
# ******* Episode   1 /   1 | Timesteps    4 | Fruits  0
#
# Fruits eaten 0.0 +/- stddev 0.0

# %% [markdown]
# ## 1. Agente con un plan determinado
#
# Vamos a construir un agente que partiendo del siguiente estado inicial:

# %%
"""
#######
#.....#
#.###.#
#..S..#
##.s..#
#.....#
#######
"""
# Out:
# '\n#######\n#.....#\n#.###.#\n#..S..#\n##.s..#\n#.....#\n#######\n'

# %% [markdown]
# llegue al siguiente estado

# %%
"""
#######
#.....#
#s###.#
#S....#
##....#
#.....#
#######
"""
# Out:
# '\n#######\n#.....#\n#s###.#\n#S....#\n##....#\n#.....#\n#######\n'

# %%
class PredefinedActionAgent(AgentBase):
    """ Represents a Snake agent that takes a random action at every step. """

    def __init__(self, actions):
        self.actions = actions
        self.step = 0
        pass

    def begin_episode(self):
        pass

    def act(self, observation, reward):
        """
        The agent takes the next action in the list of actions. Increases 
        step by 1.
        """

        if self.step >= len(self.actions):
            action = ALL_SNAKE_ACTIONS[0]
        else:
            action = self.actions[self.step]
            self.step += 1
        return action

    def end_episode(self):
        pass

inicial1 = {
  "field": [
    "#######",
    "#.....#",
    "#.###.#",
    "#..S..#",
    "##....#",
    "#.....#",
    "#######"
  ],

  "initial_snake_length": 2,
  "max_step_limit": 11,

  "rewards": {
    "timestep": -0.01,
    "ate_fruit": 1,
    "died": -1
  }
}
env = EnvironmentPO(config=inicial1, verbose=1)
agent = PredefinedActionAgent((ALL_SNAKE_ACTIONS[2], 
                               ALL_SNAKE_ACTIONS[0],
                               ALL_SNAKE_ACTIONS[1],
                               ALL_SNAKE_ACTIONS[0],
                               ALL_SNAKE_ACTIONS[1],
                               ALL_SNAKE_ACTIONS[0],
                               ALL_SNAKE_ACTIONS[0],
                               ALL_SNAKE_ACTIONS[0],
                               ALL_SNAKE_ACTIONS[1],
                               ALL_SNAKE_ACTIONS[0]))

play(env, agent, num_episodes= 1, verbose=1)
# Out:
# Playing:
# ------ Step  0  ------
# #######
# #.....#
# #.###.#
# #..S.O#
# ##.s..#
# #.....#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  1  ------
# #######
# #.....#
# #.###.#
# #..sSO#
# ##....#
# #.....#
# #######
# Observation: (4, 1, 0)
# Head: Point(x=4, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  2  ------
# #######
# #.....#
# #.###.#
# #..ssS#
# ##....#
# #...O.#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  3  ------
# #######
# #.....#
# #.###S#
# #...ss#
# ##....#
# #...O.#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  4  ------
# #######
# #....S#
# #.###s#
# #....s#
# ##....#
# #...O.#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=5, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  5  ------
# #######
# #...Ss#
# #.###s#
# #.....#
# ##....#
# #...O.#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=4, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  6  ------
# #######
# #..Sss#
# #.###.#
# #.....#
# ##....#
# #...O.#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=3, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  7  ------
# #######
# #.Sss.#
# #.###.#
# #.....#
# ##....#
# #...O.#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=2, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  8  ------
# #######
# #Sss..#
# #.###.#
# #.....#
# ##....#
# #...O.#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=1, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  9  ------
# #######
# #ss...#
# #S###.#
# #.....#
# ##....#
# #...O.#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  10  ------
# #######
# #s....#
# #s###.#
# #S....#
# ##....#
# #...O.#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=1)
# ******* Episode   1 /   1 | Timesteps   11 | Fruits  1
#
# Fruits eaten 1.0 +/- stddev 0.0

# %% [markdown]
# ## 2. Agente reactivo
#
# La idea es construir un agente reactivo, es decir que sus acciones solo dependen de la observación en un momento dado y
# no tiene memoria. El agente debe procurar no estrellarse y come cuantas frutas pueda. Compare el comportamiento de este agente con el del agente
# al azar. Simule cada agente por 100 episodios. Presente los resultados y discútalos.

# %%
class ReactiveAgent(AgentBase):
    """ 
    Represents a reactive Snake agent that dcides an action exclusively based on
    the current observation.
    """

    def __init__(self):
        pass

    def begin_episode(self):
        pass

    def act(self, observation, reward):
        """
        The agent anlizes de current observation and takes a consequent action.
        """
        # Your code here
        # Eat the fruit
        if env.get_observation()[0] == 1:
            action = ALL_SNAKE_ACTIONS[1]
        elif env.get_observation()[1] == 1:
            action = ALL_SNAKE_ACTIONS[0]
        elif env.get_observation()[2] == 1:
            action = ALL_SNAKE_ACTIONS[2]
        # Don't hit the wall
        elif env.get_observation()[1] == 4:
            if env.get_observation()[2] == 4:
                action = ALL_SNAKE_ACTIONS[1]
            elif env.get_observation()[0] == 4:
                action = ALL_SNAKE_ACTIONS[2]
          #Don't hit itself
            else:
                if env.get_observation()[0] == 3:
                    action = ALL_SNAKE_ACTIONS[2]
                elif env.get_observation()[2] == 3:
                    action = ALL_SNAKE_ACTIONS[1]
                else:
                    action = ALL_SNAKE_ACTIONS[2]
        # Don't hit itself, again
        elif env.get_observation()[1] == 3:
            if env.get_observation()[0] == 3:
                action = ALL_SNAKE_ACTIONS[2]
            elif env.get_observation()[2] == 3:
                action = ALL_SNAKE_ACTIONS[1]
          #Don't hit the wall, again
            else:
                if env.get_observation()[0] == 4:
                    action = ALL_SNAKE_ACTIONS[2]
                elif env.get_observation()[2] == 4:
                    action = ALL_SNAKE_ACTIONS[1]
                else:
                    action = ALL_SNAKE_ACTIONS[2]
        else:
            action = ALL_SNAKE_ACTIONS[0]

        return action

    def end_episode(self):
        pass
          
env = EnvironmentPO(config=inicial, verbose=1)
agent = ReactiveAgent()
play(env, agent, num_episodes= 1, verbose=1)
# Out:
# Playing:
# ------ Step  0  ------
# #######
# #.....#
# #.....#
# #..S..#
# #..s..#
# #..O..#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  1  ------
# #######
# #.....#
# #..S..#
# #..s..#
# #.....#
# #..O..#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=3, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  2  ------
# #######
# #..S..#
# #..s..#
# #.....#
# #.....#
# #..O..#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=3, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  3  ------
# #######
# #..sS.#
# #.....#
# #.....#
# #.....#
# #..O..#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  4  ------
# #######
# #...sS#
# #.....#
# #.....#
# #.....#
# #..O..#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  5  ------
# #######
# #....s#
# #....S#
# #.....#
# #.....#
# #..O..#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  6  ------
# #######
# #.....#
# #....s#
# #....S#
# #.....#
# #..O..#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  7  ------
# #######
# #.....#
# #.....#
# #....s#
# #....S#
# #..O..#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  8  ------
# #######
# #.....#
# #.....#
# #.....#
# #....s#
# #..O.S#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  9  ------
# #######
# #.....#
# #.....#
# #.....#
# #.....#
# #..OSs#
# #######
# Observation: (4, 1, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  10  ------
# #######
# #O....#
# #.....#
# #.....#
# #.....#
# #..Sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  11  ------
# #######
# #O....#
# #.....#
# #.....#
# #.....#
# #.Sss.#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  12  ------
# #######
# #O....#
# #.....#
# #.....#
# #.....#
# #Sss..#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  13  ------
# #######
# #O....#
# #.....#
# #.....#
# #S....#
# #ss...#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  14  ------
# #######
# #O....#
# #.....#
# #S....#
# #s....#
# #s....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  15  ------
# #######
# #O....#
# #S....#
# #s....#
# #s....#
# #.....#
# #######
# Observation: (4, 1, 0)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  16  ------
# #######
# #S.O..#
# #s....#
# #s....#
# #s....#
# #.....#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  17  ------
# #######
# #sSO..#
# #s....#
# #s....#
# #.....#
# #.....#
# #######
# Observation: (4, 1, 0)
# Head: Point(x=2, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  18  ------
# #######
# #ssS..#
# #s....#
# #s....#
# #...O.#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  19  ------
# #######
# #sssS.#
# #s....#
# #.....#
# #...O.#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  20  ------
# #######
# #ssssS#
# #.....#
# #.....#
# #...O.#
# #.....#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  21  ------
# #######
# #.ssss#
# #....S#
# #.....#
# #...O.#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  22  ------
# #######
# #..sss#
# #....s#
# #....S#
# #...O.#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  23  ------
# #######
# #...ss#
# #....s#
# #....s#
# #...OS#
# #.....#
# #######
# Observation: (4, 0, 1)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  24  ------
# #######
# #..Oss#
# #....s#
# #....s#
# #...Ss#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=4, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  25  ------
# #######
# #..O.s#
# #....s#
# #....s#
# #..Sss#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  26  ------
# #######
# #..O..#
# #....s#
# #....s#
# #.Ssss#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=2, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  27  ------
# #######
# #..O..#
# #.....#
# #....s#
# #Sssss#
# #.....#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=1, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  28  ------
# #######
# #..O..#
# #.....#
# #S....#
# #sssss#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  29  ------
# #######
# #..O..#
# #S....#
# #s....#
# #ssss.#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  30  ------
# #######
# #S.O..#
# #s....#
# #s....#
# #sss..#
# #.....#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  31  ------
# #######
# #sSO..#
# #s....#
# #s....#
# #ss...#
# #.....#
# #######
# Observation: (4, 1, 0)
# Head: Point(x=2, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  32  ------
# #######
# #ssS..#
# #sO...#
# #s....#
# #ss...#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  33  ------
# #######
# #sssS.#
# #sO...#
# #s....#
# #s....#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  34  ------
# #######
# #ssssS#
# #sO...#
# #s....#
# #.....#
# #.....#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  35  ------
# #######
# #sssss#
# #sO..S#
# #.....#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  36  ------
# #######
# #sssss#
# #.O..s#
# #....S#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  37  ------
# #######
# #.ssss#
# #.O..s#
# #....s#
# #....S#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  38  ------
# #######
# #..sss#
# #.O..s#
# #....s#
# #....s#
# #....S#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  39  ------
# #######
# #...ss#
# #.O..s#
# #....s#
# #....s#
# #...Ss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  40  ------
# #######
# #....s#
# #.O..s#
# #....s#
# #....s#
# #..Sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  41  ------
# #######
# #.....#
# #.O..s#
# #....s#
# #....s#
# #.Ssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  42  ------
# #######
# #.....#
# #.O...#
# #....s#
# #....s#
# #Sssss#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  43  ------
# #######
# #.....#
# #.O...#
# #.....#
# #S...s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  44  ------
# #######
# #.....#
# #.O...#
# #S....#
# #s....#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  45  ------
# #######
# #.....#
# #SO...#
# #s....#
# #s....#
# #ssss.#
# #######
# Observation: (4, 0, 1)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  46  ------
# #######
# #.....#
# #sS...#
# #s...O#
# #s....#
# #ssss.#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=2, y=2)
# Direction: Point(x=1, y=0)
# ------ Step  47  ------
# #######
# #.....#
# #ssS..#
# #s...O#
# #s....#
# #sss..#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=3, y=2)
# Direction: Point(x=1, y=0)
# ------ Step  48  ------
# #######
# #.....#
# #sssS.#
# #s...O#
# #s....#
# #ss...#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=4, y=2)
# Direction: Point(x=1, y=0)
# ------ Step  49  ------
# #######
# #.....#
# #ssssS#
# #s...O#
# #s....#
# #s....#
# #######
# Observation: (0, 4, 1)
# Head: Point(x=5, y=2)
# Direction: Point(x=1, y=0)
# ------ Step  50  ------
# #######
# #.....#
# #sssss#
# #s...S#
# #s....#
# #sO...#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  51  ------
# #######
# #.....#
# #sssss#
# #s...s#
# #s...S#
# #.O...#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  52  ------
# #######
# #.....#
# #sssss#
# #s...s#
# #....s#
# #.O..S#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  53  ------
# #######
# #.....#
# #sssss#
# #....s#
# #....s#
# #.O.Ss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  54  ------
# #######
# #.....#
# #.ssss#
# #....s#
# #....s#
# #.OSss#
# #######
# Observation: (4, 1, 0)
# Head: Point(x=3, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  55  ------
# #######
# #.....#
# #.ssss#
# #....s#
# #..O.s#
# #.Ssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  56  ------
# #######
# #.....#
# #..sss#
# #....s#
# #..O.s#
# #Sssss#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  57  ------
# #######
# #.....#
# #...ss#
# #....s#
# #S.O.s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  58  ------
# #######
# #.....#
# #....s#
# #S...s#
# #s.O.s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  59  ------
# #######
# #.....#
# #S....#
# #s...s#
# #s.O.s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  60  ------
# #######
# #S....#
# #s....#
# #s....#
# #s.O.s#
# #sssss#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  61  ------
# #######
# #sS...#
# #s....#
# #s....#
# #s.O..#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  62  ------
# #######
# #ssS..#
# #s....#
# #s....#
# #s.O..#
# #ssss.#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  63  ------
# #######
# #sssS.#
# #s....#
# #s....#
# #s.O..#
# #sss..#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  64  ------
# #######
# #ssssS#
# #s....#
# #s....#
# #s.O..#
# #ss...#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  65  ------
# #######
# #sssss#
# #s...S#
# #s....#
# #s.O..#
# #s....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  66  ------
# #######
# #sssss#
# #s...s#
# #s...S#
# #s.O..#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  67  ------
# #######
# #sssss#
# #s...s#
# #s...s#
# #..O.S#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  68  ------
# #######
# #sssss#
# #s...s#
# #....s#
# #..O.s#
# #....S#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  69  ------
# #######
# #sssss#
# #....s#
# #....s#
# #..O.s#
# #...Ss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  70  ------
# #######
# #.ssss#
# #....s#
# #....s#
# #..O.s#
# #..Sss#
# #######
# Observation: (4, 0, 1)
# Head: Point(x=3, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  71  ------
# #######
# #.ssss#
# #....s#
# #.O..s#
# #..S.s#
# #..sss#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  72  ------
# #######
# #..sss#
# #....s#
# #.OS.s#
# #..s.s#
# #..sss#
# #######
# Observation: (1, 0, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  73  ------
# #######
# #..sss#
# #....s#
# #.Ss.s#
# #..s.s#
# #O.sss#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=2, y=3)
# Direction: Point(x=-1, y=0)
# ------ Step  74  ------
# #######
# #...ss#
# #....s#
# #Sss.s#
# #..s.s#
# #O.sss#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=1, y=3)
# Direction: Point(x=-1, y=0)
# ------ Step  75  ------
# #######
# #....s#
# #S...s#
# #sss.s#
# #..s.s#
# #O.sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  76  ------
# #######
# #S....#
# #s...s#
# #sss.s#
# #..s.s#
# #O.sss#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  77  ------
# #######
# #sS...#
# #s....#
# #sss.s#
# #..s.s#
# #O.sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  78  ------
# #######
# #ssS..#
# #s....#
# #sss..#
# #..s.s#
# #O.sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  79  ------
# #######
# #sssS.#
# #s....#
# #sss..#
# #..s..#
# #O.sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  80  ------
# #######
# #ssssS#
# #s....#
# #sss..#
# #..s..#
# #O.ss.#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  81  ------
# #######
# #sssss#
# #s...S#
# #sss..#
# #..s..#
# #O.s..#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  82  ------
# #######
# #sssss#
# #s...s#
# #sss.S#
# #..s..#
# #O....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  83  ------
# #######
# #sssss#
# #s...s#
# #sss.s#
# #....S#
# #O....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  84  ------
# #######
# #sssss#
# #s...s#
# #ss..s#
# #....s#
# #O...S#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  85  ------
# #######
# #sssss#
# #s...s#
# #s...s#
# #....s#
# #O..Ss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  86  ------
# #######
# #sssss#
# #s...s#
# #....s#
# #....s#
# #O.Sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  87  ------
# #######
# #sssss#
# #....s#
# #....s#
# #....s#
# #OSsss#
# #######
# Observation: (4, 1, 0)
# Head: Point(x=2, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  88  ------
# #######
# #sssss#
# #....s#
# #....s#
# #..O.s#
# #Sssss#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  89  ------
# #######
# #.ssss#
# #....s#
# #....s#
# #S.O.s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  90  ------
# #######
# #..sss#
# #....s#
# #S...s#
# #s.O.s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  91  ------
# #######
# #...ss#
# #S...s#
# #s...s#
# #s.O.s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  92  ------
# #######
# #S...s#
# #s...s#
# #s...s#
# #s.O.s#
# #sssss#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  93  ------
# #######
# #sS...#
# #s...s#
# #s...s#
# #s.O.s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  94  ------
# #######
# #ssS..#
# #s....#
# #s...s#
# #s.O.s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  95  ------
# #######
# #sssS.#
# #s....#
# #s....#
# #s.O.s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  96  ------
# #######
# #ssssS#
# #s....#
# #s....#
# #s.O..#
# #sssss#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  97  ------
# #######
# #sssss#
# #s...S#
# #s....#
# #s.O..#
# #ssss.#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  98  ------
# #######
# #sssss#
# #s...s#
# #s...S#
# #s.O..#
# #sss..#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  99  ------
# #######
# #sssss#
# #s...s#
# #s...s#
# #s.O.S#
# #ss...#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  100  ------
# #######
# #sssss#
# #s...s#
# #s...s#
# #s.O.s#
# #s...S#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  101  ------
# #######
# #sssss#
# #s...s#
# #s...s#
# #s.O.s#
# #...Ss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  102  ------
# #######
# #sssss#
# #s...s#
# #s...s#
# #..O.s#
# #..Sss#
# #######
# Observation: (4, 0, 1)
# Head: Point(x=3, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  103  ------
# #######
# #sssss#
# #sO..s#
# #s...s#
# #..S.s#
# #..sss#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  104  ------
# #######
# #sssss#
# #sO..s#
# #..S.s#
# #..s.s#
# #..sss#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  105  ------
# #######
# #sssss#
# #.OS.s#
# #..s.s#
# #..s.s#
# #..sss#
# #######
# Observation: (1, 3, 0)
# Head: Point(x=3, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  106  ------
# #######
# #sssss#
# #.Ss.s#
# #..s.s#
# #O.s.s#
# #..sss#
# #######
# Observation: (0, 0, 3)
# Head: Point(x=2, y=2)
# Direction: Point(x=-1, y=0)
# ------ Step  107  ------
# #######
# #.ssss#
# #Sss.s#
# #..s.s#
# #O.s.s#
# #..sss#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=1, y=2)
# Direction: Point(x=-1, y=0)
# ------ Step  108  ------
# #######
# #S.sss#
# #sss.s#
# #..s.s#
# #O.s.s#
# #..sss#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  109  ------
# #######
# #sS.ss#
# #sss.s#
# #..s.s#
# #O.s.s#
# #..sss#
# #######
# Observation: (4, 0, 3)
# Head: Point(x=2, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  110  ------
# #######
# #ssS.s#
# #sss.s#
# #..s.s#
# #O.s.s#
# #..sss#
# #######
# Observation: (4, 0, 3)
# Head: Point(x=3, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  111  ------
# #######
# #sssS.#
# #sss.s#
# #..s.s#
# #O.s.s#
# #..sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  112  ------
# #######
# #ssssS#
# #sss..#
# #..s.s#
# #O.s.s#
# #..sss#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  113  ------
# #######
# #sssss#
# #sss.S#
# #..s..#
# #O.s.s#
# #..sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  114  ------
# #######
# #sssss#
# #sss.s#
# #..s.S#
# #O.s..#
# #..sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  115  ------
# #######
# #sssss#
# #sss.s#
# #..s.s#
# #O.s.S#
# #..ss.#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  116  ------
# #######
# #sssss#
# #sss.s#
# #..s.s#
# #O.s.s#
# #..s.S#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  117  ------
# #######
# #sssss#
# #sss.s#
# #..s.s#
# #O.s.s#
# #...Ss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  118  ------
# #######
# #sssss#
# #sss.s#
# #..s.s#
# #O...s#
# #..Sss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  119  ------
# #######
# #sssss#
# #sss.s#
# #....s#
# #O...s#
# #.Ssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  120  ------
# #######
# #sssss#
# #ss..s#
# #....s#
# #O...s#
# #Sssss#
# #######
# Observation: (4, 4, 1)
# Head: Point(x=1, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  121  ------
# #######
# #sssss#
# #ss..s#
# #.O..s#
# #S...s#
# #sssss#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  122  ------
# #######
# #sssss#
# #s...s#
# #SO..s#
# #s...s#
# #sssss#
# #######
# Observation: (4, 3, 1)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  123  ------
# #######
# #sssss#
# #s...s#
# #sS..s#
# #s.O.s#
# #sssss#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=2, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  124  ------
# #######
# #sssss#
# #....s#
# #ssS.s#
# #s.O.s#
# #sssss#
# #######
# Observation: (0, 0, 1)
# Head: Point(x=3, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  125  ------
# #######
# #sssss#
# #.O..s#
# #sss.s#
# #s.S.s#
# #sssss#
# #######
# Observation: (0, 3, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  126  ------
# #######
# #.ssss#
# #.O..s#
# #sss.s#
# #sSs.s#
# #sssss#
# #######
# Observation: (3, 3, 3)
# Head: Point(x=2, y=4)
# Direction: Point(x=-1, y=0)
# ******* Episode   1 /   1 | Timesteps  127 | Fruits 16
#
# Fruits eaten 16.0 +/- stddev 0.0

# %%
print("AGENTE ALEATORIO")
env = EnvironmentPO(config=inicial, verbose=1)
agent = RandomActionAgent()
play(env, agent, num_episodes= 100, verbose=0)
# Out:
# AGENTE ALEATORIO
#
# Playing:
# ******* Episode   1 / 100 | Timesteps    8 | Fruits  1
# ******* Episode   2 / 100 | Timesteps    5 | Fruits  0
# ******* Episode   3 / 100 | Timesteps    3 | Fruits  0
# ******* Episode   4 / 100 | Timesteps    8 | Fruits  1
# ******* Episode   5 / 100 | Timesteps    5 | Fruits  1
# ******* Episode   6 / 100 | Timesteps    5 | Fruits  0
# ******* Episode   7 / 100 | Timesteps    5 | Fruits  0
# ******* Episode   8 / 100 | Timesteps    4 | Fruits  0
# ******* Episode   9 / 100 | Timesteps    6 | Fruits  1
# ******* Episode  10 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  11 / 100 | Timesteps    6 | Fruits  0
# ******* Episode  12 / 100 | Timesteps   11 | Fruits  0
# ******* Episode  13 / 100 | Timesteps    9 | Fruits  0
# ******* Episode  14 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  15 / 100 | Timesteps    4 | Fruits  1
# ******* Episode  16 / 100 | Timesteps    7 | Fruits  0
# ******* Episode  17 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  18 / 100 | Timesteps    4 | Fruits  1
# ******* Episode  19 / 100 | Timesteps    6 | Fruits  2
# ******* Episode  20 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  21 / 100 | Timesteps   16 | Fruits  0
# ******* Episode  22 / 100 | Timesteps   17 | Fruits  1
# ******* Episode  23 / 100 | Timesteps    4 | Fruits  1
# ******* Episode  24 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  25 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  26 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  27 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  28 / 100 | Timesteps    7 | Fruits  1
# ******* Episode  29 / 100 | Timesteps    8 | Fruits  1
# ******* Episode  30 / 100 | Timesteps   14 | Fruits  0
# ******* Episode  31 / 100 | Timesteps   13 | Fruits  1
# ******* Episode  32 / 100 | Timesteps    7 | Fruits  0
# ******* Episode  33 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  34 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  35 / 100 | Timesteps    6 | Fruits  1
# ******* Episode  36 / 100 | Timesteps    6 | Fruits  0
# ******* Episode  37 / 100 | Timesteps    7 | Fruits  0
# ******* Episode  38 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  39 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  40 / 100 | Timesteps    3 | Fruits  0
# ******* Episode  41 / 100 | Timesteps    6 | Fruits  1
# ******* Episode  42 / 100 | Timesteps   12 | Fruits  0
# ******* Episode  43 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  44 / 100 | Timesteps    5 | Fruits  1
# ******* Episode  45 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  46 / 100 | Timesteps    7 | Fruits  0
# ******* Episode  47 / 100 | Timesteps    3 | Fruits  1
# ******* Episode  48 / 100 | Timesteps    7 | Fruits  0
# ******* Episode  49 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  50 / 100 | Timesteps   10 | Fruits  2
# ******* Episode  51 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  52 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  53 / 100 | Timesteps   12 | Fruits  0
# ******* Episode  54 / 100 | Timesteps    4 | Fruits  1
# ******* Episode  55 / 100 | Timesteps   14 | Fruits  0
# ******* Episode  56 / 100 | Timesteps   11 | Fruits  0
# ******* Episode  57 / 100 | Timesteps   10 | Fruits  1
# ******* Episode  58 / 100 | Timesteps   23 | Fruits  2
# ******* Episode  59 / 100 | Timesteps    7 | Fruits  0
# ******* Episode  60 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  61 / 100 | Timesteps   12 | Fruits  0
# ******* Episode  62 / 100 | Timesteps    5 | Fruits  1
# ******* Episode  63 / 100 | Timesteps   14 | Fruits  0
# ******* Episode  64 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  65 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  66 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  67 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  68 / 100 | Timesteps   11 | Fruits  1
# ******* Episode  69 / 100 | Timesteps    9 | Fruits  1
# ******* Episode  70 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  71 / 100 | Timesteps    7 | Fruits  0
# ******* Episode  72 / 100 | Timesteps    3 | Fruits  0
# ******* Episode  73 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  74 / 100 | Timesteps   11 | Fruits  1
# ******* Episode  75 / 100 | Timesteps    3 | Fruits  0
# ******* Episode  76 / 100 | Timesteps    9 | Fruits  1
# ******* Episode  77 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  78 / 100 | Timesteps    4 | Fruits  1
# ******* Episode  79 / 100 | Timesteps    9 | Fruits  0
# ******* Episode  80 / 100 | Timesteps    3 | Fruits  0
# ******* Episode  81 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  82 / 100 | Timesteps    5 | Fruits  1
# ******* Episode  83 / 100 | Timesteps   11 | Fruits  2
# ******* Episode  84 / 100 | Timesteps   11 | Fruits  0
# ******* Episode  85 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  86 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  87 / 100 | Timesteps    9 | Fruits  0
# ******* Episode  88 / 100 | Timesteps    5 | Fruits  1
# ******* Episode  89 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  90 / 100 | Timesteps    4 | Fruits  0
# ******* Episode  91 / 100 | Timesteps    8 | Fruits  0
# ******* Episode  92 / 100 | Timesteps    8 | Fruits  0
# ******* Episode  93 / 100 | Timesteps    6 | Fruits  0
# ******* Episode  94 / 100 | Timesteps    7 | Fruits  0
# ******* Episode  95 / 100 | Timesteps    7 | Fruits  0
# ******* Episode  96 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  97 / 100 | Timesteps   11 | Fruits  0
# ******* Episode  98 / 100 | Timesteps    5 | Fruits  0
# ******* Episode  99 / 100 | Timesteps    7 | Fruits  0
# ******* Episode 100 / 100 | Timesteps    8 | Fruits  0
#
# Fruits eaten 0.3 +/- stddev 0.5

# %%
print("AGENTE REACTIVO")
env = EnvironmentPO(config=inicial, verbose=1)
agent = ReactiveAgent()
play(env, agent, num_episodes= 100, verbose=0)
# Out:
# AGENTE REACTIVO
#
# Playing:
# ******* Episode   1 / 100 | Timesteps 1000 | Fruits  9
# ******* Episode   2 / 100 | Timesteps   80 | Fruits 15
# ******* Episode   3 / 100 | Timesteps   87 | Fruits 10
# ******* Episode   4 / 100 | Timesteps   93 | Fruits 11
# ******* Episode   5 / 100 | Timesteps 1000 | Fruits  9
# ******* Episode   6 / 100 | Timesteps   47 | Fruits 14
# ******* Episode   7 / 100 | Timesteps 1000 | Fruits  3
# ******* Episode   8 / 100 | Timesteps  135 | Fruits 22
# ******* Episode   9 / 100 | Timesteps 1000 | Fruits  2
# ******* Episode  10 / 100 | Timesteps   73 | Fruits 10
# ******* Episode  11 / 100 | Timesteps   63 | Fruits 10
# ******* Episode  12 / 100 | Timesteps   75 | Fruits 10
# ******* Episode  13 / 100 | Timesteps   57 | Fruits  8
# ******* Episode  14 / 100 | Timesteps   81 | Fruits 12
# ******* Episode  15 / 100 | Timesteps   68 | Fruits 11
# ******* Episode  16 / 100 | Timesteps  101 | Fruits 13
# ******* Episode  17 / 100 | Timesteps  113 | Fruits 16
# ******* Episode  18 / 100 | Timesteps 1000 | Fruits  1
# ******* Episode  19 / 100 | Timesteps   89 | Fruits 11
# ******* Episode  20 / 100 | Timesteps  105 | Fruits 15
# ******* Episode  21 / 100 | Timesteps 1000 | Fruits  3
# ******* Episode  22 / 100 | Timesteps   89 | Fruits 12
# ******* Episode  23 / 100 | Timesteps 1000 | Fruits  7
# ******* Episode  24 / 100 | Timesteps   41 | Fruits  8
# ******* Episode  25 / 100 | Timesteps   57 | Fruits 10
# ******* Episode  26 / 100 | Timesteps   87 | Fruits 12
# ******* Episode  27 / 100 | Timesteps   49 | Fruits  9
# ******* Episode  28 / 100 | Timesteps  105 | Fruits 17
# ******* Episode  29 / 100 | Timesteps   59 | Fruits 10
# ******* Episode  30 / 100 | Timesteps   61 | Fruits 10
# ******* Episode  31 / 100 | Timesteps 1000 | Fruits  4
# ******* Episode  32 / 100 | Timesteps   85 | Fruits 16
# ******* Episode  33 / 100 | Timesteps   75 | Fruits 15
# ******* Episode  34 / 100 | Timesteps  107 | Fruits 12
# ******* Episode  35 / 100 | Timesteps 1000 | Fruits  7
# ******* Episode  36 / 100 | Timesteps   85 | Fruits 12
# ******* Episode  37 / 100 | Timesteps 1000 | Fruits  6
# ******* Episode  38 / 100 | Timesteps 1000 | Fruits  5
# ******* Episode  39 / 100 | Timesteps   94 | Fruits 13
# ******* Episode  40 / 100 | Timesteps   73 | Fruits 10
# ******* Episode  41 / 100 | Timesteps 1000 | Fruits  3
# ******* Episode  42 / 100 | Timesteps   71 | Fruits 11
# ******* Episode  43 / 100 | Timesteps 1000 | Fruits  3
# ******* Episode  44 / 100 | Timesteps   67 | Fruits  8
# ******* Episode  45 / 100 | Timesteps 1000 | Fruits  9
# ******* Episode  46 / 100 | Timesteps   91 | Fruits 13
# ******* Episode  47 / 100 | Timesteps  100 | Fruits 10
# ******* Episode  48 / 100 | Timesteps 1000 | Fruits  2
# ******* Episode  49 / 100 | Timesteps  139 | Fruits 22
# ******* Episode  50 / 100 | Timesteps   64 | Fruits 13
# ******* Episode  51 / 100 | Timesteps   70 | Fruits  8
# ******* Episode  52 / 100 | Timesteps  103 | Fruits 15
# ******* Episode  53 / 100 | Timesteps 1000 | Fruits  5
# ******* Episode  54 / 100 | Timesteps   77 | Fruits 13
# ******* Episode  55 / 100 | Timesteps   65 | Fruits 10
# ******* Episode  56 / 100 | Timesteps   99 | Fruits 13
# ******* Episode  57 / 100 | Timesteps 1000 | Fruits  6
# ******* Episode  58 / 100 | Timesteps   92 | Fruits 10
# ******* Episode  59 / 100 | Timesteps   44 | Fruits  6
# ******* Episode  60 / 100 | Timesteps 1000 | Fruits  4
# ******* Episode  61 / 100 | Timesteps   99 | Fruits 13
# ******* Episode  62 / 100 | Timesteps  109 | Fruits 12
# ******* Episode  63 / 100 | Timesteps   75 | Fruits 13
# ******* Episode  64 / 100 | Timesteps   99 | Fruits 15
# ******* Episode  65 / 100 | Timesteps   87 | Fruits 13
# ******* Episode  66 / 100 | Timesteps   28 | Fruits  7
# ******* Episode  67 / 100 | Timesteps 1000 | Fruits  7
# ******* Episode  68 / 100 | Timesteps   59 | Fruits 10
# ******* Episode  69 / 100 | Timesteps 1000 | Fruits  5
# ******* Episode  70 / 100 | Timesteps   55 | Fruits  9
# ******* Episode  71 / 100 | Timesteps 1000 | Fruits  4
# ******* Episode  72 / 100 | Timesteps   69 | Fruits 12
# ******* Episode  73 / 100 | Timesteps   59 | Fruits 12
# ******* Episode  74 / 100 | Timesteps   45 | Fruits  8
# ******* Episode  75 / 100 | Timesteps  103 | Fruits 11
# ******* Episode  76 / 100 | Timesteps   83 | Fruits 14
# ******* Episode  77 / 100 | Timesteps   91 | Fruits  9
# ******* Episode  78 / 100 | Timesteps   58 | Fruits 11
# ******* Episode  79 / 100 | Timesteps   73 | Fruits 16
# ******* Episode  80 / 100 | Timesteps   54 | Fruits 11
# ******* Episode  81 / 100 | Timesteps   51 | Fruits 10
# ******* Episode  82 / 100 | Timesteps   43 | Fruits  6
# ******* Episode  83 / 100 | Timesteps 1000 | Fruits  5
# ******* Episode  84 / 100 | Timesteps   56 | Fruits 10
# ******* Episode  85 / 100 | Timesteps   97 | Fruits 11
# ******* Episode  86 / 100 | Timesteps   59 | Fruits 11
# ******* Episode  87 / 100 | Timesteps   53 | Fruits  8
# ******* Episode  88 / 100 | Timesteps   76 | Fruits 12
# ******* Episode  89 / 100 | Timesteps   53 | Fruits 12
# ******* Episode  90 / 100 | Timesteps   67 | Fruits 10
# ******* Episode  91 / 100 | Timesteps 1000 | Fruits 11
# ******* Episode  92 / 100 | Timesteps   65 | Fruits  8
# ******* Episode  93 / 100 | Timesteps   77 | Fruits  9
# ******* Episode  94 / 100 | Timesteps  113 | Fruits 12
# ******* Episode  95 / 100 | Timesteps  104 | Fruits 11
# ******* Episode  96 / 100 | Timesteps 1000 | Fruits  1
# ******* Episode  97 / 100 | Timesteps   81 | Fruits 18
# ******* Episode  98 / 100 | Timesteps   69 | Fruits 11
# ******* Episode  99 / 100 | Timesteps   81 | Fruits 11
# ******* Episode 100 / 100 | Timesteps   85 | Fruits 17
#
# Fruits eaten 10.1 +/- stddev 4.1

# %% [markdown]
# **Resultados:**
#
# Se evidencia que el agente reactivo es mucho más efectivo que el agente aleatorio. El promedio de frutas que comió el agente reactivo es mucho mayor al del agente aleatorio.
#
# No hubo ningún caso en que el agente reactivo no hubiera comido al menos una fruta antes de morir, a diferencia del agente aleatorio.
